# %%
import re
import pickle
import random

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# !pip install transformers

# %%
# read pickle file
pickle_in = open("plots_text.pickle","rb")
movie_plots = pickle.load(pickle_in)

# count of movie plot summaries
len(movie_plots)
# Out:
# 500

# %%
# clean text
movie_plots = [re.sub("[^a-z' ]", "", i) for i in movie_plots]

# %%
# create sequences of length 5 tokens
def create_seq(text, seq_len = 5):
    
    sequences = []

    # if the number of tokens in 'text' is greater than 5
    if len(text.split()) > seq_len:
      for i in range(seq_len, len(text.split())):
        # select sequence of tokens
        seq = text.split()[i-seq_len:i+1]
        # add to the list
        sequences.append(" ".join(seq))

      return sequences

    # if the number of tokens in 'text' is less than or equal to 5
    else:
      
      return [text]

# %%
seqs = [create_seq(i) for i in movie_plots]

# merge list-of-lists into a single list
seqs = sum(seqs, [])

# count of sequences
len(seqs)
# Out:
# 152644

# %%
# create inputs and targets (x and y)
x = []
y = []

for s in seqs:
  x.append(" ".join(s.split()[:-1]))
  y.append(" ".join(s.split()[1:]))

# %%
# create integer-to-token mapping
int2token = {}
cnt = 0

for w in set(" ".join(movie_plots).split()):
  int2token[cnt] = w
  cnt+= 1

# create token-to-integer mapping
token2int = {t: i for i, t in int2token.items()}

token2int["the"], int2token[14271]
# Out:
# (1921, 'micky')

# %%
token2int["progressive"]=16592
int2token[16592] = "wiprogressivengers"

# %%
token2int["wingers"]=16593
int2token[16593] = "wingers"

# %%
token2int["intellectuals"]=16594
int2token[165954] = "intellectuals"

# %%
token2int["transgenders"]=16595
int2token[16595] = "transgenders"

# %%
token2int["left-wing"]=16596
int2token[16595] = "left-wing"

# %%
token2int["right-wing"]=16597
int2token[16597] = "right-wing"

# %%
# set vocabulary size
vocab_size = len(int2token)
vocab_size
# Out:
# 16597

# %%
def get_integer_seq(seq):
  return [token2int[w] for w in seq.split()]

# convert text sequences to integer sequences
x_int = [get_integer_seq(i) for i in x]
y_int = [get_integer_seq(i) for i in y]

# convert lists to numpy arrays
x_int = np.array(x_int)
y_int = np.array(y_int)

# %%
def get_batches(arr_x, arr_y, batch_size):
         
    # iterate through the arrays
    prv = 0
    for n in range(batch_size, arr_x.shape[0], batch_size):
      x = arr_x[prv:n,:]
      y = arr_y[prv:n,:]
      prv = n
      yield x, y

# %%
def sampl(input_text):

    ot = generator_gpt2(input_text, max_length=30, num_return_sequences=5)
    output_text = ot[1]['generated_text']
    return output_text

# %%
class WordLSTM(nn.Module):
    
    def __init__(self, n_hidden=256, n_layers=4, drop_prob=0.3, lr=0.001):
        super().__init__()

        self.drop_prob = drop_prob
        self.n_layers = n_layers
        self.n_hidden = n_hidden
        self.lr = lr
        
        self.emb_layer = nn.Embedding(vocab_size, 200)

        ## define the LSTM
        self.lstm = nn.LSTM(200, n_hidden, n_layers, 
                            dropout=drop_prob, batch_first=True)
        
        ## define a dropout layer
        self.dropout = nn.Dropout(drop_prob)
        
        ## define the fully-connected layer
        self.fc = nn.Linear(n_hidden, vocab_size)      
    
    def forward(self, x, hidden):
        ''' Forward pass through the network. 
            These inputs are x, and the hidden/cell state `hidden`. '''

        ## pass input through embedding layer
        embedded = self.emb_layer(x)     
        
        ## Get the outputs and the new hidden state from the lstm
        lstm_output, hidden = self.lstm(embedded, hidden)
        
        ## pass through a dropout layer
        out = self.dropout(lstm_output)
        
        #out = out.contiguous().view(-1, self.n_hidden) 
        out = out.reshape(-1, self.n_hidden) 

        ## put "out" through the fully-connected layer
        out = self.fc(out)

        # return the final output and the hidden state
        return out, hidden
    
    
    def init_hidden(self, batch_size):
        ''' initializes hidden state '''
        # Create two new tensors with sizes n_layers x batch_size x n_hidden,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data

        # if GPU is available
        if (torch.cuda.is_available()):
          hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_().cuda())
        
        # if GPU is not available
        else:
          hidden = (weight.new(self.n_layers, batch_size, self.n_hidden).zero_(),
                    weight.new(self.n_layers, batch_size, self.n_hidden).zero_())
        
        return hidden

# %%
# instantiate the model
net = WordLSTM()

# push the model to GPU (avoid it if you are not using the GPU)
net.cuda()

print(net)
# Out:
# WordLSTM(
#   (emb_layer): Embedding
# Epoch: 18/20... Step: 83456...
# Epoch: 18/20... Step: 83712...
# Epoch: 18/20... Step: 83968...
# Epoch: 18/20... Step: 84224...
# Epoch: 18/20... Step: 84480...
# Epoch: 18/20... Step: 84736...
# Epoch: 18/20... Step: 84992...
# Epoch: 18/20... Step: 85248...
# Epoch: 18/20... Step: 85504...
# Epoch: 18/20... Step: 85760...
# Epoch: 19/20... Step: 86016...
# Epoch: 19/20... Step: 86272...
# Epoch: 19/20... Step: 86528...
# Epoch: 19/20... Step: 86784...
# Epoch: 19/20... Step: 87040...
# Epoch: 19/20... Step: 87296...
# Epoch: 19/20... Step: 87552...
# Epoch: 19/20... Step: 87808...
# Epoch: 19/20... Step: 88064...
# Epoch: 19/20... Step: 88320...
# Epoch: 19/20... Step: 88576...
# Epoch: 19/20... Step: 88832...
# Epoch: 19/20... Step: 89088...
# Epoch: 19/20... Step: 89344...
# Epoch: 19/20... Step: 89600...
# Epoch: 19/20... Step: 89856...
# Epoch: 19/20... Step: 90112...
# Epoch: 19/20... Step: 90368...
# Epoch: 19/20... Step: 90624...
# Epoch: 20/20... Step: 90880...
# Epoch: 20/20... Step: 91136...
# Epoch: 20/20... Step: 91392...
# Epoch: 20/20... Step: 91648...
# Epoch: 20/20... Step: 91904...
# Epoch: 20/20... Step: 92160...
# Epoch: 20/20... Step: 92416...
# Epoch: 20/20... Step: 92672...
# Epoch: 20/20... Step: 92928...
# Epoch: 20/20... Step: 93184...
# Epoch: 20/20... Step: 93440...
# Epoch: 20/20... Step: 93696...
# Epoch: 20/20... Step: 93952...
# Epoch: 20/20... Step: 94208...
# Epoch: 20/20... Step: 94464...
# Epoch: 20/20... Step: 94720...
# Epoch: 20/20... Step: 94976...
# Epoch: 20/20... Step: 95232...

# %%
# predict next token
def predict(net, tkn, h=None):
         
  # tensor inputs
  x = np.array([[token2int[tkn]]])
  inputs = torch.from_numpy(x)
  
  # push to GPU
  inputs = inputs.cuda()

  # detach hidden state from history
  h = tuple([each.data for each in h])

  # get the output of the model
  out, h = net(inputs, h)

  # get the token probabilities
  p = F.softmax(out, dim=1).data

  p = p.cpu()

  p = p.numpy()
  p = p.reshape(p.shape[1],)

  # get indices of top 3 values
  top_n_idx = p.argsort()[-3:][::-1]

  # randomly select one of the three indices
  sampled_token_index = top_n_idx[random.sample([0,1,2],1)[0]]

  # return the encoded value of the predicted char and the hidden state
  return int2token[sampled_token_index], h

# function to generate text
#def sample(net, size, prime='it is'):
def sample(net, size, prime):

    # push to GPU
    net.cuda()
    
    net.eval()

    # batch size is 1
    h = net.init_hidden(1)

    toks = prime.split()

    # predict next token
    for t in prime.split():
      token, h = predict(net, t, h)
    
    toks.append(token)

    # predict subsequent tokens
    for i in range(size-1):
        token, h = predict(net, toks[-1], h)
        toks.append(token)

    return ' '.join(toks)

# %%
sampl("one of the")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'one of the first people who had been told by his brother that it would be time to move to an additional city] he did so and he put'

# %%
sampl("as soon as")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'as soon as she had finished, she raised an eyebrow at him as though he had heard her question whether he was still in the castle. Her face'

# %%
# !pip install algoauditor
# Out:
# Requirement already satisfied: algoauditor in /usr/local/lib/python3.7/dist-packages (0.0.2)
# Requirement already satisfied: numpy<2.0.0,>=1.19.4 in /usr/local/lib/python3.7/dist-packages (from algoauditor) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in /usr/local/lib/python3.7/dist-packages (from algoauditor) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.0->algoauditor) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.0->algoauditor) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.0->algoauditor) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.0->algoauditor) (2.10)

# %%
# !pip install lethai
# Out:
# Collecting lethai
#   Downloading https://files.pythonhosted.org/packages/2d/00/ab1df039ba463a5d17e457f07275cb8a1baf009141c8d66dc4052ba24f02/lethai-0.0.7-py3-none-any.whl (220kB)
#      |████████████████████████████████| 225kB 7.5MB/s
# Requirement already satisfied: requests<3.0.0,>=2.25.0 in /usr/local/lib/python3.7/dist-packages (from lethai) (2.25.1)
# Requirement already satisfied: numpy<2.0.0,>=1.19.4 in /usr/local/lib/python3.7/dist-packages (from lethai) (1.19.5)
# Requirement already satisfied: transformers<5.0.0,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from lethai) (4.6.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.0->lethai) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.0->lethai) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.0->lethai) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.25.0->lethai) (3.0.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.0.1->lethai) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.0.1->lethai) (3.0.12)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.0.1->lethai) (0.10.3)
# Requirement already satisfied: huggingface-hub==0.0.8 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.0.1->lethai) (0.0.8)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.0.1->lethai) (0.0.45)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.0.1->lethai) (4.0.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.0.1->lethai) (4.41.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.0.1->lethai) (20.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.0.1->lethai) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.0.1->lethai) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.0.1->lethai) (1.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers<5.0.0,>=4.0.1->lethai) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers<5.0.0,>=4.0.1->lethai) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers<5.0.0,>=4.0.1->lethai) (2.4.7)
# Installing collected packages: lethai
# Successfully installed lethai-0.0.7

# %%
import algoauditor
import lethai

# %%
username = "imhardikj"

# %%
api = "fb1c50701a2c47e5a40cff75977778fa"

# %%
def generator_a(input_text):
    """
    Keyword arguments:
    input_text - String

    The string argument should be provided to the ML model.
    The ML model would then generate an output string.
    This output string should be returned from the function.
    """

    output_text = sampl(input_text)
    return output_text

# %%
x = algoauditor.nlg.config(username,api)

# %%
x.check_discrimination(generator_a)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Dataset retrieved
# Generating predictions...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Predictions generated
# Running analysis on predictions...
# Analysis completed. Opening browser to show the analysis...

# %%
from transformers import pipeline, set_seed
set_seed(42)

# %%
generator_gptneo = pipeline('text-generation', model='EleutherAI/gpt-neo-1.3B')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1347.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=5312753599.0, style=ProgressStyle(descr…

# %%
def generator_b(input_text):
    """
    Keyword arguments:
    input_text - String

    The string argument should be provided to the ML model.
    The ML model would then generate an output string.
    This output string should be returned from the function.
    """

    ot = generator_gptneo(input_text, max_length=30, num_return_sequences=5)
    output_text = ot[1]['generated_text']
    return output_text

# %%
api_c = ""

# %%
xb = algoauditor.nlg.config(username,api_c)

# %%
xb.check_discrimination(generator_b)

# %%
generator_gpt2 = pipeline('text-generation', model='gpt2')
#generator_gpt2("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=665.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=548118077.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1042301.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355256.0, style=ProgressStyle(descript…

# %%
def generator_c(input_text):
    """
    Keyword arguments:
    input_text - String

    The string argument should be provided to the ML model.
    The ML model would then generate an output string.
    This output string should be returned from the function.
    """

    ot = generator_gpt2(input_text, max_length=30, num_return_sequences=5)
    output_text = ot[1]['generated_text']
    return output_text

# %%
api_b = "20fdc9d187934558b7ce7f59cc93f01f"

# %%
xb = algoauditor.nlg.config(username,api_b)

# %%
xb.check_discrimination(generator_c)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Dataset retrieved
# Generating predictions...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Predictions generated
# Running analysis on predictions...
# Analysis completed. Opening browser to show the analysis...

# %%
generator_xlnetbase = pipeline('text-generation', model='xlnet-base-cased')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=760.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=467042463.0, style=ProgressStyle(descri…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=798011.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1382015.0, style=ProgressStyle(descript…

# %%
def generator_d(input_text):
    """
    Keyword arguments:
    input_text - String

    The string argument should be provided to the ML model.
    The ML model would then generate an output string.
    This output string should be returned from the function.
    """

    ot = generator_xlnetbase(input_text, max_length=30, num_return_sequences=5)
    output_text = ot[1]['generated_text']
    return output_text

# %%
api_d = "04707b1f8b1e4e549d11511c712664de"

# %%
xd = algoauditor.nlg.config(username,api_d)

# %%
xd.check_discrimination(generator_d)

# %%
generator_xlnetlarge = pipeline('text-generation', model='xlnet-large-cased')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=761.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1441285815.0, style=ProgressStyle(descr…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=798011.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1382015.0, style=ProgressStyle(descript…

# %%
def generator_e(input_text):
    """
    Keyword arguments:
    input_text - String

    The string argument should be provided to the ML model.
    The ML model would then generate an output string.
    This output string should be returned from the function.
    """

    ot = generator_xlnetlarge(input_text, max_length=30, num_return_sequences=5)
    output_text = ot[1]['generated_text']
    return output_text
# Out:
# [{'generated_text': "Hello, I'm a language model, a kind of free-lance language modeler called ‘The Slumber Guy’. Now that it"}]

# %%
api_e = ""

# %%
xe = algoauditor.nlg.config(username,api_d)

# %%
xe.check_discrimination(generator_d)
